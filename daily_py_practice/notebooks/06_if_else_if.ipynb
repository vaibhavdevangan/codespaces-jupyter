# %%
hotel_rate = 150

numyears = int(input("Enter number of years married: "))
if numyears == 50:
    print('congratulations on your 50 years of marriage  anniversary!')
    hotel_rate = hotel_rate / 2

print(f'The hotel rate is: ${hotel_rate} per night.')
# Out:
# congratulations on your 50 years of marriage  anniversary!
# The hotel rate is: $75.0 per night.

# %% [markdown]
# ## If-else statement:

# %%
user_num = int(input("Enter a number: "))
div_remainder = user_num % 2
if div_remainder == 0:
    print(f'{user_num} is even.')
else:
    print(f'{user_num} is odd.')
# Out:
# 6 is even.

# %% [markdown]
# ## Multi-branch if-else example:

# %%
num_years = int(input( 'Enter number years married: '))
if num_years == 1 :
    print( "Your first year great!" )
elif num_years == 10:
    print("A whole decade impressive." )
elif num_years == 25:
    print("your silver anniversary -- enjoy.")
elif num_years == 50:
    print("Your golden anniversary -- amazing.")
else:
    print("Nothing special.")
# Out:
# Your first year great!
