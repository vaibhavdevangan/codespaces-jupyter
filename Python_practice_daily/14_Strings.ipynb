# %% [markdown]
# String slicing basics

# %%
my_str = 'Bhavesh'

print(my_str[5])
# Out:
# s

# %%
my_str = 'Bhavesh'

print(my_str[0:3])
# Out:
# Bha

# %%
url = 'https://www.pythonacademy.in/'
domain = url[8:28]
print(domain)
# Out:
# www.pythonacademy.in

# %%
my_str = 'Jayesh Patel?'

print(my_str[0:-2])
# Out:
# Jayesh Pate

# %%
my_str = "The cat jumped the brown cow"

animal = my_str[4:7]
print(f'The animal is a {animal}')


my_str = 'The fox jumped the brown 11ama'
print(f'The animal is still a', animal) # animal variable remains unchanged
# Out:
# The animal is a cat
# The animal is still a cat

# %% [markdown]
# ## Slice stride

# %%
numbers = '0123456789'

print(f'All numbers: {numbers[ : : ]}' )


print(f'Every even number: {numbers[: : 2]}' )


print(f'Every third number between 1 and 8: {numbers[1:9:3]}')
# Out:
# All numbers: 0123456789
# Every even number: 02468
# Every third number between 1 and 8: 147

# %%
names = ['Sadio Mane', 'Gabriel Jesus' ]
goals = [22, 7]

print(f'{"Player Name":<16}{"Goals":<8}')  #Replaced in table below

print('-' * 24)
for i in range(2):
    print(f'{names[i]:<16}{goals[i]:<8}')
# Out:
# Player Name     Goals
# ------------------------
# Sadio Mane      22
# Gabriel Jesus   7

# %%
# String formatting example: Setting precision of floating-point values
import math
real_pi = math.pi # math library provides close approximation of pi
approximate_pi = 22.0 / 7.0 # Approximately correct pi to within 2 decimal places

print(f'pi is {real_pi}')
print(f'22/7 is {approximate_pi}')
print(f'22/7 looks better like {approximate_pi:.2f}')
# Out:
# pi is 3.141592653589793
# 22/7 is 3.142857142857143
# 22/7 looks better like 3.14

# %% [markdown]
# ## 7.3 String methods

# %%
phrase = 'One day I will have three goats, six horses, and nine llamas.'

# Replace English with Spanish.
phrase = phrase.replace('one', 'uno' )
phrase = phrase. replace('two', 'dos' )
phrase = phrase.replace('three', 'tres' )
phrase = phrase. replace('four', 'cuatro' )
phrase = phrase.replace('five', 'cinco' )
phrase = phrase.replace('six', 'seis' )
phrase = phrase.replace('seven', 'siete' )
phrase = phrase.replace('eight', 'ocho' )
phrase = phrase.replace('nine', 'nueve' )

print('Translation:', phrase)
# Out:
# Translation: One day I will have tres goats, seis horses, and nueve llamas.

# %%
#  Use 'in' to check if a character or substring is contained by another string

superhero_name = "batman forever"

if 'batman' in superhero_name:
# Statements to execute if superhero_name contains 'batman' in any position.
    print("The superhero name contains 'batman'.")
else:
    print("The superhero name does not contain 'batman' .")
# Out:
# The superhero name contains 'batman'.

# %% [markdown]
# ### Identity vs. equality operators : is vs ==

# %% [markdown]
# is operator:

# %%
student_name = input('Enter student name: \n' )

if student_name is 'Anup Kelkar':
    print('Identity operator: True')
else:
    print('Identity operator: False' )
# Out:
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# Identity operator: False
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15412\1965328866.py:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if student_name is 'Anup Kelkar':

# %% [markdown]
# == operator

# %%
student_name = input('Enter student name: \n' )

if student_name == 'Anup Kelkar':
    print('Equality operator: True' )
else:
    print('Equality operator: False' )
# Out:
# Equality operator: False

# %% [markdown]
# <!-- Methods to check a string value that
# returns a True or False Boolean value:
#     isalnum() -- Returns True if all characters in the string are
#                  lowercase or uppercase letters, or the numbers 0-9.
#     isdigit() -- Returns True if all characters are the numbers 0-9.
#     islower() -- Returns True if all cased characters are lowercase letters.
#     isupper() -- Return True if all cased characters are uppercase letters.
#     isspace() -- Return True if all characters are whitespace.
#     startswith(x) -- Return True if the string starts with x.
#     endswith(x) -- Return True if the string ends with x. -->

# %%
name = input().strip().lower()
#return into lower and space truncated for whatever str input is given 
print(name)
# Out:
# rgfg

# %% [markdown]
# ## 7.4 Splitting and joining strings
# Splitting a string into tokens

# %%
string = 'Music/artist/song.mp3'
my_tokens = string. split('/')  # returns the Substrings into a elements of list
print(my_tokens)


string = 'I love python'
my_tokens = string. split()
print(my_tokens)
# Out:
# ['Music', 'artist', 'song.mp3']
# ['I', 'love', 'python']

# %% [markdown]
# String split example

# %%
url = input('Enter URL:\n')

tokens = url.split('/') # Uses '/' separator\
print("input URL :",url)
print(tokens)
# Out:
# input URL : rg
# ['rg']

# %% [markdown]
# #### String join() method

# %%
my_str = '@'.join(['billgates', 'microsoft']) 
my_str
# Out:
# 'billgates@microsoft'

# %%
web_path = ['www.website.com','profile','settings']
separator = '/'
url = separator.join(web_path)
print(url)
# Out:
# www.website.com/profile/settings

# %% [markdown]
# #### String join() example: Comparing join vs. loops
#
# The following programs are equivalent, but join() is a simpler approach that uses less code and is easier to read.

# %%
#joining with loops
phrases = ['To be, ', 'or not to be. \n', 'That is the question. ']

sentence = ''
for phrase in phrases:
    sentence += phrase
    print(sentence)



#joining with join() func
phrases = ['To be, ', 'or not to be. \n', 'That is the question.']
sentence = ''.join(phrases)
# Out:
# To be,
# To be, or not to be.
#
# To be, or not to be.
# That is the question.

# %%
# Splitting and joining: Replacing separators

path = input('Enter file name: ')

new_separator = input('Enter new separator:')
tokens = path. split('/')
print(new_separator.join(tokens))
# Out:
# rgr
