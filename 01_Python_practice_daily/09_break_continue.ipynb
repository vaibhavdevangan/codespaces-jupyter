# %%
for c in "python":
    print(c)
# Out:
# p
# y
# t
# h
# o
# n

# %% [markdown]
# #### break statement

# %%
for c in "python":
    if c == "t":
        break
    print(c)

print("done")
# Out:
# p
# y
# done

# %%
for c in "python":
    if c == "t":
        continue
    print(c)

print("done")
# Out:
# p
# y
# h
# o
# n
# done

# %%
mult = 0
a = 4
b = 5
c = 20
while a < 10:
     mult = b * a 
     if mult > c: 
        break 
     a = a + 1 
     z = a
print("The multiplication is:", mult)
print("The final value of a is:", z)
# Out:
# The multiplication is: 25
# The final value of a is: 5

# %%
for num in range(1, 10): # range(start, stop) stop not included
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
