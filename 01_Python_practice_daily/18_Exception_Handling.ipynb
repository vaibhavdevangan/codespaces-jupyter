# %%
# BMI example without exception handling

user_input = ''
while user_input != 'q':
    weight = int(input("Enter weight (in pounds): "))
    height = int(input("Enter height (in inches): "))

    bmi = (float(weight) / float(height * height)) * 703
    print('BMI:', bmi)
    print('(CDC: 18.6-24.9 normal)\n')
# Source www.cdc.gov66

    user_input = input("Enter any key ('q' to quit): ")
# Out:
# BMI: 24.207988980716255
# (CDC: 18.6-24.9 normal)

# %%
# BMI example with exception handling using try/except

user_input = ''
while user_input != 'q':

    try:
        weight = int(input("Enter weight (in pounds):"))
        height = int(input("Enter height (in inches): "))

        bmi = (float(weight) / float(height * height)) * 703
        print('BMI:', bmi)
        print('(CDC: 18.6-24.9 normal)\n') # Source www.cdc.gov
    except:
        print('Could not calculate health info. \n')
    user_input = input("Enter any key ('q' to quit) : ")
# Out:
# Could not calculate health info.
#
# Could not calculate health info.
#
# BMI: 15466.0
# (CDC: 18.6-24.9 normal)
#
# Could not calculate health info.
#
# Could not calculate health info.
#
# Could not calculate health info.
#
# Could not calculate health info.
#
# Could not calculate health info.

# %%
user_input = ''
while user_input != 'q':
    try:
        weight = int(input("Enter weight (in pounds): "))
        height = int(input("Enter height (in inches): "))

        bmi = (float(weight) / float(height * height)) * 703
        print('BMI:', bmi)
        print('(CDC: 18.6-24.9 normal)\n')
    except ValueError:
        print('Could not calculate health info. \n')
    except ZeroDivisionError:
        print('Invalid height entered. Must be > 0.' )

    user_input = input("Enter any key ('q' to quit): ")

    # Source www.cdc.gov
# Out:
# Could not calculate health info.
#
# Could not calculate health info.
#
# Could not calculate health info.
#
# Could not calculate health info.
#
# Could not calculate health info.

# %%
# BMI example using exception-handling constructs along with functions

def get_weight():
    weight = int(input('Enter weight (in pounds): '))
    if weight < 0:
     raise ValueError('Invalid weight.')
    return weight

def get_height():
    height = int(input('Enter height (in inches): '))
    if height <= 0:
        raise ValueError('Invalid height.')
    return height

user_input = ''
while user_input != 'q':
    try:
        weight = get_weight()
        height = get_height()


        bmi = (float(weight) / float(height * height)) * 703
        print('BMI:', bmi)
        print('(CDC: 18.6-24.9 normal)\n')
        # Source www.cdc.gov

    except ValueError as excpt:
        print(excpt)
        print('Could not calculate health info. \n')

    user_input = input("Enter any key ('q' to quit): ")
# Out:
# BMI: 24.207988980716255
# (CDC: 18.6-24.9 normal)

# %%
def divide(a, b):
    z = -1
    try:
        z = a / b
    except ZeroDivisionError:
        print('Cannot divide by zero')
    finally:
        print('Result is',z)

divide(10,2)
# Out:
# Result is 5.0

# %%
# Custom exception types

# Define a custom exception type
class LessThanZeroError(Exception):
    def _init_(self, value):
    
        self.value = value

my_num = int(input('Enter number: '))

if my_num < 0:
    raise LessThanZeroError('my_num must be greater than 0')
else:
    print('my_num:', my_num)
# Out:
# ---------------------------------------------------------------------------
# LessThanZeroError                         Traceback (most recent call last)
# Cell In[11], line 12
#       9 my_num = int(input('Enter number: '))
#      11 if my_num < 0:
# ---> 12     raise LessThanZeroError('my_num must be greater than 0')
#      13 else:
#      14     print('my_num:', my_num)
#
# LessThanZeroError: my_num must be greater than 0
