# %%
#while else

names = ['Jayesh' , 'Chetan', 'Manish' , 'Varsha' , 'Jai']

num = int(input('Enter number of names to print: '))
for i in range(len(names)):
    if i == num:
        break
    print(names[i],end=' ')
else:
    print("\nAll names printed.")


    #jr loop purn complete zala manje last condition false zali 
    #tarach else block execute hoto
    #jr loop break statement mule exit zala 
    # tarach else block execute hot nahi
# Out:
# Jayesh Chetan Manish Varsha Jai
# All names printed.

# %%
#for else

x= 0
y = 5
z = int(input('Enter a number: '))   

while x < y:
    if x == z:
        print('x is equal to z')
        break
    x += 1

else: # no break staement executed
    print('x==y')
# Out:
# x==y
